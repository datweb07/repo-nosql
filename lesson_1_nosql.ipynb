# %%
# !python -m pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 12.3 MB/s eta 0:00:00
# ...

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://dat82770_db_user:1XqK3zRaL49InS9c@cluster01.2anwnf3.mongodb.net/?appName=Cluster01"

client = MongoClient(uri, server_api=ServerApi('1'))

try:
    client.admin.command('ping')
    print("Kết nối MongoDB thành công!")
except Exception as e:
    print(e)
# Out:
# Kết nối MongoDB thành công!

# %%
db = client.QLSV

collection_sv = db.sinhvien

# sv1 = {
#     "masv": "240001",
#     "hoten": "Nguyen Van An",
#     "chuyennganh": {"manganh": "KHMT", "tennganh": "Khoa hoc may tinh"},
#     "dienthoai": ["0123456", "0567899"]
# }
# collection_sv.insert_one(sv1)
# print("Đã thêm 1 sinh viên!")


# tap_sv2 = [
#     {"masv": "240002", "hoten": "Dam Vinh Hoa", "tuoi": 20},
#     {"masv": "240003", "hoten": "Luu Duc Nhan", "tuoi": 22}
# ]
# collection_sv.insert_many(tap_sv2)
# print("Đã thêm danh sách sinh viên!")

print("Tất cả sinh viên")
for sv in collection_sv.find():
    print(sv)


print("Lấy sv có mã sv là '240001")
for sv in collection_sv.find(
    {
        "masv": "240001"
    }
):
    print(sv)


print("Lấy sv lớn hơn 20 tuổi")
for sv in collection_sv.find(
    {
        "tuoi": {
            "$gt": 20
        }
    }
):
    print(sv)
    print(sv)
# Out:
# Tất cả sinh viên
# {'_id': ObjectId('69eb6f9998b764899e0de4c5'), 'masv': '240001', 'hoten': 'Nguyen Van B', 'chuyennganh': {'manganh': 'KHMT', 'tennganh': 'Khoa hoc may tinh'}, 'dienthoai': ['0123456', '0567899']}
# {'_id': ObjectId('69eb6f9998b764899e0de4c6'), 'masv': '240002', 'hoten': 'Dam Vinh Hoa', 'tuoi': 20}
# {'_id': ObjectId('69eb6f9998b764899e0de4c7'), 'masv': '240003', 'hoten': 'Luu Duc Nhan', 'tuoi': 22}
# Lấy sv có mã sv là '240001
# {'_id': ObjectId('69eb6f9998b764899e0de4c5'), 'masv': '240001', 'hoten': 'Nguyen Van B', 'chuyennganh': {'manganh': 'KHMT', 'tennganh': 'Khoa hoc may tinh'}, 'dienthoai': ['0123456', '0567899']}
# Lấy sv lớn hơn 20 tuổi
# {'_id': ObjectId('69eb6f9998b764899e0de4c7'), 'masv': '240003', 'hoten': 'Luu Duc Nhan', 'tuoi': 22}
# {'_id': ObjectId('69eb6f9998b764899e0de4c7'), 'masv': '240003', 'hoten': 'Luu Duc Nhan', 'tuoi': 22}

# %%
dieu_kien = {
    'masv' : '240001'
}
cap_nhat = {
    '$set': {
        'hoten': 'Nguyen Van B'
    }
}

collection_sv.update_one(dieu_kien, cap_nhat)
print("Đã cập nhật sinh viên!")
# Out:
# Đã cập nhật sinh viên!

# %%
print("Tất cả sinh viên")
for sv in collection_sv.find():
    print(sv)
# Out:
# Tất cả sinh viên
# {'_id': ObjectId('69eb6f9998b764899e0de4c5'), 'masv': '240001', 'hoten': 'Nguyen Van B', 'chuyennganh': {'manganh': 'KHMT', 'tennganh': 'Khoa hoc may tinh'}, 'dienthoai': ['0123456', '0567899']}
# {'_id': ObjectId('69eb6f9998b764899e0de4c6'), 'masv': '240002', 'hoten': 'Dam Vinh Hoa', 'tuoi': 20}
# {'_id': ObjectId('69eb6f9998b764899e0de4c7'), 'masv': '240003', 'hoten': 'Luu Duc Nhan', 'tuoi': 22}

# %%
qlphim = client["qlphim"]

# %%
from datetime import datetime
p = {
    "maphim" : "P01", "tenphim" : "Phim so 01", "thoigian" : 90,
    "theloai" : [
        "H", "HD"
    ],
    "ctychieu" : [
         {
            "macty" : "CGVV",
            "ngbd" : datetime(2024, 12, 25, 0, 0, 0),
            "ngkt" : datetime(2025, 1, 20, 0, 0, 0),
            "slsuat" : 100, 'tongsove': 15000
         },
         {
            "macty" : "LOT",
            "ngbd" : datetime(2024, 12, 27, 0, 0, 0),
            "ngkt" : datetime(2025, 1, 15, 0, 0, 0),
            "slsuat" : 80, 'tongsove': 9000
         }
    ],
    "daodien": "Nguyen Van A",
    "dienvien": [
        { 'ten': "AAAA", 'tuoi': 19, 'theloaidien': ["TC", "HD"] },
        { 'ten': "BBBB", "tuoi": 22, 'theloaidien': ["TC", "H", "KD"] }
    ],
    'tuoitoithieu' : 18
}
ps = [
{
    "maphim" : "P02", "tenphim" : "Phim so 02", "thoigian" : 120,
    "theloai" : [
        "H", "HD", "KD"
    ],
    "ctychieu" : [
         {
            "macty" : "CGVV",
            "ngbd" : datetime(2025, 2, 25, 0, 0, 0),
            "ngkt" : datetime(2025, 3, 20, 0, 0, 0),
            "slsuat" : 120, 'tongsove': 13000
         }
    ],
    "daodien": "Nguyen Van B",
    "dienvien": [
        { 'ten': "CCC", 'tuoi': 29, 'theloaidien': ["H", "KD"] },
        { 'ten': "BBBB", "tuoi": 22, 'theloaidien': ["TC", "H", "KD"] }
    ],
    'tuoitoithieu' : 15
},
{
    "maphim" : "P03", "tenphim" : "Phim so 03", "thoigian" : 75,
    "theloai" : [
        "TC"
    ],
    "ctychieu" : [
         {
            "macty" : "LOT",
            "ngbd" : datetime(2025, 1, 25, 0, 0, 0),
            "ngkt" : datetime(2025, 2, 20, 0, 0, 0),
            "slsuat" : 110, 'tongsove': 13000
         }
    ],
    "daodien": "Nguyen Van A",
    "dienvien": [
        { 'ten': "CCC", 'tuoi': 29, 'theloaidien': ["H", "KD"] },
        { 'ten': "DDD", "tuoi": 25, 'theloaidien': ["HD"] }
    ],
    'tuoitoithieu' : 18
}
]

qlphim["phim"].insert_one(p)
qlphim["phim"].insert_many(ps)
ds = qlphim["phim"].find()
for i in ds: print(i)
# Out:
# {'_id': ObjectId('69eb7f6598b764899e0de4ce'), 'maphim': 'P01', 'tenphim': 'Phim so 01', 'thoigian': 90, 'theloai': ['H', 'HD'], 'ctychieu': [{'macty': 'CGVV', 'ngbd': datetime.datetime(2024, 12, 25, 0, 0), 'ngkt': datetime.datetime(2025, 1, 20, 0, 0), 'slsuat': 100, 'tongsove': 15000}, {'macty': 'LOT', 'ngbd': datetime.datetime(2024, 12, 27, 0, 0), 'ngkt': datetime.datetime(2025, 1, 15, 0, 0), 'slsuat': 80, 'tongsove': 9000}], 'daodien': 'Nguyen Van A', 'dienvien': [{'ten': 'AAAA', 'tuoi': 19, 'theloaidien': ['TC', 'HD']}, {'ten': 'BBBB', 'tuoi': 22, 'theloaidien': ['TC', 'H', 'KD']}], 'tuoitoithieu': 18}
# ...
